# %% [markdown]
# <div align="center">
#
#   # 🚀 365 Days Building, Learning and Growing Together
#
#   ## 📡 MCP Servers
#   ### <span style="color: #ffd700;">Day_22</span> • 10-Jan-2026
#
#   ---
#
#   <strong>🖊️ Author:</strong> Khurram Shahzad &nbsp;&nbsp;&nbsp;&nbsp;
#   <strong>🎓 Mentor:</strong> Dr. Aammar Tufail
#
#   ---
#
#   <a href="mailto:khurramamq@gmail.com">✉️ Email</a> &nbsp;&nbsp;&nbsp;&nbsp;
#   <a href="https://github.com/zkskhurram/365_Dyas_Growing_Together" target="_blank">💻 GitHub</a>&nbsp;&nbsp;&nbsp;&nbsp;
#   <a href="https://www.kaggle.com/zkskhurram"> 📊kaggle</a>
#
#   ---
#
#   <span style="background: #667eea; color: white; padding: 5px 15px; border-radius: 20px;">🎯 AI Tools</span>
#   <span style="background: #1dbb79; color: white; padding: 5px 15px; border-radius: 20px;">🔎 EDA</span>
#   <span style="background: #7817c3; color: white; padding: 5px 15px; border-radius: 20px;">🐍 Python</span>
#   <span style="background: #ce4e09; color: white; padding: 5px 15px; border-radius: 20px;">🤖 Data Science</span>
# </div>
#
#
# ---

# %% [markdown]
# # 🤖 **Understanding MCP: The Grammar of AI Agents** 🧠
#
# <div style="background: linear-gradient(90deg, #1e3c72, #2a5298); padding: 20px; border-radius: 15px; color: white; text-align: center;">
# <h2 style="color: white;">📡 Model Context Protocol (MCP) - Complete Guide</h2>
# <p style="font-size: 16px;">🔥 The Hottest Buzzword in AI Agents Right Now!</p>
# </div>
#
# ## 📋 **Lecture Overview**
# - **Topic**: Model Context Protocol (MCP)
# - **Focus**: Understanding the "grammar" of AI agents
# - **Level**: Advanced AI Concepts Made Simple
#
# ---
#
# <div style="background: #f8f9fa; padding: 15px; border-left: 5px solid #4361ee; border-radius: 5px; color: #202124;">
# <h3>🎯 What You'll Learn:</h3>
# <ul>
# <li>What MCP is and why it's everywhere</li>
# <li>How agentic AI takes ACTION (not just gives info)</li>
# <li>MCP as the "grammar" of AI agents</li>
# <li>Real-world examples & frameworks</li>
# <li>Benefits & practical applications</li>
# </ul>
# </div>

# %% [markdown]
# ## 🎬 **Introduction: The MCP Buzzword**
#
# In the name of Allah, the Most Merciful. Assalam-o-Alaikum again.
#
# And now the thing we're going to talk about is—**that is MCP**.
#
# 🚨 **MCP, MCP, MCP—it's everywhere right now!**
#
# If you talk about AI agents, I will give you an introduction right now, then we'll talk about it and we will also use it later on in this course.

# %% [markdown]
# ## 📖 **What is MCP?**
#
# MCP basically is a **Model Context Protocol** that is used inside **agentic AI**.

# %% [markdown]
# ## 🦾 **Understanding Agentic AI**
#
# Now, I have told you before what agentic AI is. **Agentic AI is an AI that can typically take an action.**
#
# > 💡 **Key Insight**: It's an AI in which **action is involved**—meaning it doesn't just give you information, but it also **takes action**.
#
# ### 📝 **Example: Calendar Check**
# I had given an example: if you tell agentic AI, for example,
# "**Check my schedule for next Thursday and tell me what I'm doing,**" it looks at your calendar and tells you your schedule.
#
# Or you tell it, "**Okay, which time is free?**" it tells you you're free from 1 to 2:00. Right?
#
# So you can tell it: "**Okay, that was information. Now take an action.**"
#
# What is the action?
# Write there: "**I have to prepare the lecture.**" Or if I have to do something—then it basically **takes that action on your behalf** and performs that work. Right?
#
# 🤖 **And agents—AI agents—are being used a lot.**
#
# One hot term for them is **Model Context Protocol**. What is this? How does it work? Let's talk a little about it.
#
# ⚡ This is a **game changer** for AI and LLM applications—especially for AI agents.
#
# > 🎯 **Prediction**: If you follow on YouTube the people who teach AI—especially in Western countries—this is going to be a huge buzzword in these few weeks, I would say.

# %% [markdown]
# ## 🔗 **How MCP Works: The Technical Foundation**
#
# How does MCP work inside a large language model system?
#
# Listen carefully. First we read the definition, then we understand it.
#
# ---
#
# ## 🧠 **MCP in Simple Terms**
#
# Mostly, MCP right now is being used with agents—to build AI agents.
#
# What are agents? **AI that takes action on your behalf.** Remember just this much.

# %% [markdown]
# ## 📐 **Breaking Down the Name**
#
# MCP is a **Model Context Protocol**—meaning a protocol that links with the model's context. Got it?
#
# ### What is a Protocol?
# 🔍 **Standardized protocol**. What is a protocol? It's a **pathway** through which computers talk to each other.
#
# A protocol is nothing but that.
#
# - **HTTPS** comes with every website. That means it's a protocol basically that is talking to bring the website.
# - **SSH** is a protocol—shell script service—and there are many protocols.
#
# 📡 **Protocol means**: when computers talk to each other, through whatever language or pathway.
# >A standardized **protocol for managing and passing context** between a LLM and its **tools, memory, agents and components.**

# %% [markdown]
# ## 🎯 **The Complete MCP Definition**
#
# A standardized protocol for **managing and passing context**.
#
# So they are not only talking, but they are managing and passing what? **CONTEXT.**
#
# > 💭 **What is context?** Your information or data on which the large language model has to answer you.
#
# - If it's **RAG**, then your PDF documents are the context.
# - Context is whatever information you are giving.
#
# ### 🔄 **Between Whom?**
# Between:
# 1. The **large language model** and the **large language model's tools**
# 2. The large language model has **memory**
# 3. It has **agents**
# 4. And **system components**
#
# These are **four things**: **Tools, Memory, Agents, and System Components.**
#
# Shifting the context of these four with each other—inside a large language model—that happens through **MCP**.

# %% [markdown]
# ## 🏠 **The House Analogy: MCP Explained Simply**
#
# An example: you live in a house.
#
# New information comes, you tell your little sister, "**Don't tell anyone.**"
#
# She tells your mom, tells your dad. And at the end, **everyone in the house knows.**
#
# 🏡 **So our house became an MCP server**: information came in, it reached everyone.
#
# The kid—whatever you told her—she added one or two things from her side, or reduced one or two things. Meaning she didn't tell the exact same thing.
#
# 🔄 **So MCP servers basically work like this**: a place where a large language model talks with its context—tools, memory, agents, and system components.

# %% [markdown]
# ## 🗣️ **MCP: The GRAMMAR of AI Agents**
#
# Now see: MCP, Model Context Protocol—this is the **grammar of AI agents.**
#
# 💡 **Meaning**: how AI agents think, how they work, or how they will respond—this is their grammar. Got it?
#
# MCP is their grammar. I told you: context protocol—how they talk to each other. This is their grammar: MCP.
#
# It defines how LLMs don't just talk—but **THINK** and **ACT** inside advanced applications.
#
# ---
#
# ### 📝 **Simple Summary**
# MCP is the grammar of an AI agent.
#
# - How they think
# - How they talk
# - How they take action
#
# MCP handles all of this. That's why MCP is a buzzword right now.
#
# > 🎯 This means if you have an MCP, inside that MCP there is information about how AI agents will work. Simple—nothing more than that.

# %% [markdown]
# ## 🤔 **Why is MCP Necessary?**
#
# Why is Model Context Protocol necessary?
#
# ### 🎯 **LLMs Work Best With Structured Input**
#
# Large language models work best when they are given **structured input**, meaning context.
#
# They:
# 1. Know the **role** they are playing ("Act as a developer," "Act as a researcher")
# 2. Can **call tools** and maintain **memory**
#
# What is memory? When you ask a question, then you ask another related one, it has saved the previous question inside the context—that's called memory.
#
# 3. Can be **paused, resumed, and redirected**
#
# > 💡 **So meaning**: if these characteristics are in an LLM, they work at their best.
#
# ### 🚀 **What Does MCP Do?**
#
# It defines a **universal way to format that input/output**—so LLMs can behave consistently across apps.
#
# Meaning: how to think the input and output, how to talk, and what all is involved—MCP makes the large language model even stronger. And it's used a lot inside agentic AI or agents.

# %% [markdown]
# ## ⚙️ **Core Features of MCP**
#
# ### 🗃️ **1. Input/Output Schema Management**
# This box you might have seen—this creates a schematic for input/output messages: what is input, what is output.
#
# ### 🧠 **2. Memory, Tools & Thought Process**
# It includes memory, tools, and your thought process.
#
# ### 🔗 **3. Multi-Turn, Multi-Agent, Multi-Step Reasoning**
# It supports:
# - Multi-turn interactions
# - Multi-agent coordination
# - Multi-step reasoning
#
# > 🧮 **All these models like O3, O1, or DeepSeek—these are reasoning models—these basically use MCP.**
#
# Got it? If you have MCP, it means you can create your own agents.
#
# ### 🔄 **4. Context Replay, Editing & Branching**
# MCP enables context replay, editing, and branching. I have given a very good example so you understand schema, tools, memory, thought process, and other things.

# %% [markdown]
# ## ✈️ **The Flight Plan Analogy**
#
# Now here is an example of how MCP works—think of it like an **LLM flight plan**.
#
# ---
#
# ## 🌤️ **Real Example: Weather Query**
#
# ### 👤 **User Asks:**
# "**What's the weather?**"
#
# ### 🤖 **Agent Plays a Role:**
# It is a "**get weather**" tool. Now the tool is "get weather." Understand? Role, context.
#
# ### 🔧 **Tool Execution:**
# The tool is get weather. It sets location as **Lahore** and asks: what is the weather? Then that tool basically gets you the answer.
#
# ### 🔄 **The Flow:**
# User asked "What's the weather?" → The agent said: get weather from here → The tool does that work → The agent defines it and gives it.
#
# > 💡 **Meaning the agent is that thing—AI agent—that is working as you.**
#
# ### 🧠 **Context Intelligence:**
# Now I explain again: I am the user. I asked: "What's the weather?" It automatically understood that in my previous context or somewhere, location Lahore was set.
#
# The agent said: based on search history, Lahore is discussed more, so give it Lahore. Or the IP is Pakistan's and Punjab's IP, so ask Lahore. **So the agent is taking action.**
#
# 📍 **You need to provide permissions.**
#
# ### 📤 **Final Response:**
# It says: Lahore weather— I didn't say that. I only said: how is the weather? **The agent itself took action.** It asked the tool: what is Lahore's weather? The tool told: **24°C, sunny.**
#
# Now another agent is telling: it's **24°C and sunny in Lahore.** It converted the same thing forward.
#
# 🎯 **This is how MCP works.**

# %% [markdown]
# ## 🔄 **What Does MCP Do?**
#
# What does MCP do? It structures this interaction—so it's **replayable, editable, and interoperable** between agents and tools.
#
# That's MCP's job: **user, agent, tools, agent role—connecting all of these.**
#
# > 💡 **Back to definition**: What does Model Context Protocol do? It connects the LLM to tools, memory, agents, and system components, and shares information.
#
# What information was shared here? Weather was asked. Weather was shared forward. Answer came. That information was converted into output. Input, output, and everything—MCP handled.
#
# 🎯 **And this is the simplest example of MCP.**
#
# Understood till here?

# %% [markdown]
# ## 📊 **How Agents Use MCP: The Diagram Explained**
#
# ### 🔄 **The Flow:**
#
# 1. 👤 **User asked a question** from the large language model.
#
# 2. 📡 **MCP standardized context passing** to the LLM. What you asked went through MCP into the large language model.
#
# 3. 🧠 **LLM did reasoning**. MCP standardized the context you asked.
#
# 4. 🔧 **Agents, memory, and tools also saw it**. Together they created your response.
#
# > 💡 **Again**: you only asked the question. The rest of the conversation is happening inside the LLM and its components.
#
# 5. 📤 **LLM using all components** and its own vocabulary to give you a standardized response.
#
# Meaning: in your response, it's not just the LLM's role, but also the **Model Context Protocol's role**.
#
# Processing the context and giving you a refined form—that is reasoning. And it's not just "a question came and finished." It's more than that.
#
# 🧩 **You must have seen**: especially reasoning models—inside them MCP control servers run—MCP context protocol servers run.

# %% [markdown]
# ## 🌍 **How MCP Works Inside LLM Context**
#
# ### 📝 **Example with Location Context:**
#
# For example: you give an input while living in Pakistan, in Urdu or English. It first goes to the MCP server.
#
# ### 🖥️ **MCP Server Components:**
#
# MCP server has different types of tools:
#
# 1. **Large Language Model**—GPT, Claude, some other models
# 2. **Tools Sector**:
#    - Weather
#    - Calculator—what to do
#
# Tool means: for the problem, which software or application should be used.
#
# #### 🧮 **Calculator Tool Example:**
# Like if it's **2 + 5**, it will use the calculator tool.
#
# #### 🌐 **API Tool Example:**
# If I need World Bank data, it will use an API as a tool.
#
# #### 🌤️ **Weather Tool Example:**
# If I'm asking weather, it will use a weather API.
#
# #### 🤖 **LLM Component:**
# Which algorithm—GPT or which one.
#
# #### 💾 **Memory Store:**
# What does it do? It stores past chat history. So maybe when I asked "What's the weather?" I had asked something about Lahore earlier—that was stored. So everything is connected.
#
# ### 📤 **Final Response:**
# At the end, your final response goes to the user. And inside that response you get all information based on these things: model and its components—tools, memory, and other system components. But these two are very important to understand for reasoning.
#
# 🎯 **This is how MCP works.**

# %% [markdown]
# ## 🚀 **MCP Frameworks & Ecosystem**
#
# MCP has different frameworks and uses. For example:
#
# ### 1. **OpenDevin** 🛠️
# This is a framework that uses MCP. And agent-tool interaction exists inside it.
#
# ---
#
# ### 2. **AgentOps** 🧠
# For **memory and orchestration**. You use AgentOps.
#
# ---
#
# ### 3. **LangGraph** 🔗
# Is used for **pluggable schema support**. You do different plugging inside it:
# - Which LLM to take
# - Which tool to take
# - Which memory store to take
#
# Then you make a chain, LangGraph—like LangChain, similarly LangGraph.
#
# ---
#
# ### 4. **CrewAI & Auto** 👥
# These are **custom context handling** MCP frameworks.
#
# ---
#
# > 💡 **Till here understood?** What are MCPs, how they are, why they are, what they are, and how they work.

# %% [markdown]
# ## ⭐ **Benefits of MCP**
#
# Now what are the benefits of MCP? And this is like a really advanced level of AI agent—but of course it's easy to understand.
#
# ### ✅ **1. Structured, Standardized Interactions**
# These are structured, standardized interactions. And these structured and standardized interactions happen only because of MCP—because in this protocol you define MCPs.
#
# And there are big companies who have provided MCP—Model Context Protocol—for you. And I'm gonna show you that.
#
# ### 🐛 **2. Easier Debugging & Logging**
# There are websites where you will get MCP servers. Easier for debugging and logging. If you have to create error logs and do debugging, it's very easy through this.
#
# Because agents talk to each other and bring things into a solution.
#
# ### 🔌 **3. Tools Interoperability & Plug-and-Play**
# You just connect tools to each other and everything will be working together.
#
# ### 🎮 **4. Complex AI Workflows Made Simple**
# Enables complex AI workflows and simulations in the easiest possible manner.
#
# ### 👥 **5. Multi-Agent Coordination**
# Supports multi-agent coordination. There is one thing: making a simple agent. Now you can also make **multiple agents** using MCP servers.
#
# ---
#
# ### 🖥️ **What is an MCP Server?**
# A Model Context Protocol that someone basically designed and you have it available, and then you can download it.

# %% [markdown]
# ## 📚 **Additional Resources**
#
# Now if you want to read an article—"**Looking Beyond the Hype: What's MCP all about?**"—do read this article.
#
# In it, Model Context Protocol is defined in a very good way. This is the title of that article.
#
# 🔍 **Search on Google**—you will find it out.

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(90deg, #4361ee, #3a0ca3); padding: 30px; border-radius: 15px; color: white; text-align: center;">
# <h2 style="color: white;">🎉 Summary: Key Takeaways</h2>
# <p style="font-size: 16px;">
# ✨ MCP is the <strong>grammar</strong> of AI agents<br>
# 🤖 It enables <strong>action-taking</strong>, not just information<br>
# 🔄 Connects LLMs to <strong>tools, memory, agents & systems</strong><br>
# 🧠 Makes AI workflows <strong>structured & interoperable</strong><br>
# 🚀 The future of <strong>agentic AI architecture</strong>
# </p>
# </div>
#
# ---
#
# <div style="text-align: center; padding: 20px;">
# <h3>🔮 Happy Learning & Keep Building! 🔧</h3>
# <p>Share this notebook if you found it helpful! ⭐</p>
# </div>
