# %% [markdown]
# <div div style="background-color: #2E2E2E; padding: 30px; border-radius: 10px; text-align: center; border: 3px solid #FFD700;">
#
#   # 📅🌱🤝 365 Dyas Building , Learning adn Growing Together
#   ## 🤖 🤖 Large Language Models & AI 🤖
#   ### ⚡ For Data Analysts: Understanding LLMs & Their Role in Data Analytics
#   #### <strong>🎯 Focus:</strong> Solving Real-World Problems | <strong>💡 Key:</strong> Execution Over Ideas</p>
#
#   <div style="text-align: center; margin-top: 30px;">
#   <span style="background: #e94560; color: white; padding: 10px 20px; border-radius: 25px; font-weight: bold; margin: 5px;"> 📅 Day 43 </span>
#   <span style="background: #ffd700; color: #1a1a2e; padding: 10px 20px; border-radius: 25px; font-weight: bold; margin: 5px;"> 👉 📅 03-Mar-2026 </span>
#   <span style="background: #cf10b6; color: #1a1a2e; padding: 10px 20px; border-radius: 25px; font-weight: bold; margin: 5px;"> 📅➡️ 365 Days </span>
#   </div>
#
#   ---
#
#   <strong>🖊️ Author:</strong> Khurram Shahzad &nbsp;&nbsp;&nbsp;&nbsp;
#   <strong>🎓 Mentor:</strong> Dr. Aammar Tufail
#
#   ---
#
#   <a href="mailto:khurramamq@gmail.com">✉️ Email</a> &nbsp;&nbsp;&nbsp;&nbsp;
#   <a href="https://github.com/zkskhurram/365_Dyas_Growing_Together" target="_blank">💻 GitHub</a>&nbsp;&nbsp;&nbsp;&nbsp;
#   <a href="https://www.kaggle.com/zkskhurram"> 📊kaggle</a>
#
#   ---
#
#   <span style="background: #667eea; color: white; padding: 5px 15px; border-radius: 20px;">🎯 AI Tools</span>
#   <span style="background: #1dbb79; color: white; padding: 5px 15px; border-radius: 20px;">🔎 EDA</span>
#   <span style="background: #7817c3; color: white; padding: 5px 15px; border-radius: 20px;">🐍 Python</span>
#   <span style="background: #ce4e09; color: white; padding: 5px 15px; border-radius: 20px;">🤖 Data Science</span>
#    <span style="background: #10627b; color: white; padding: 5px 15px; border-radius: 20px;">🤖 LLM</span>
# </div>
#
# ----
#
# </div>

# %% [markdown]
# <div style="background-color: #0F3460; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🌟 Introduction: The Two Things Dominating the World</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Bismillah hir-Rahman nir-Rahim. I will start this lecture with just two things: <strong style="color: #FFD700;">Large Language Models</strong> and <strong style="color: #FFD700;">AI</strong>.</p>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">These are the two things that are dominating the world right now. One is Large Language Models, and the second is AI. What are these? How do we work with them? I will explain this to you. And what is their role in Data Analytics? The screen is in front of you.</p>
# <div style="background-color: #16213e; padding: 20px; border-radius: 10px; margin-top: 20px; border: 2px solid #E94560;">
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin: 0;">🎯 First, I will explain Large Language Models - what they are. You have to understand this very easily, and we have to utilize this to teach us how to deal with data.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #2D132C; padding: 30px; border-radius: 15px; border-left: 8px solid #EE4540; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🔍 From Google It to ChatGPT It</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Many of you have already heard a very famous name - <strong style="color: #FFD700;">ChatGPT</strong>. In the old days (I mean 5 years ago, before Large Language Models like ChatGPT came), a terminology had developed. People used to say, Just Google it.</p>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px dashed #FFD700;">
# <h3 style="color: #EE4540; margin-top: 0;">🤣 The Famous Joke</h3>
# <p style="color: #ffffff; font-style: italic; font-size: 1.1em;">Mera bhai nahi mil raha (I cannot find my brother) → Yaar, mera bhai nahi mil raha → Google kar lo! (Just Google it!)</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin-top: 20px;">
# <h3 style="color: #FFD700; margin-top: 0;">⏰ The Old Era is Gone!</h3>
# <p style="color: #ffffff; font-size: 1.1em; margin: 0;">The kind of things we were doing using Google - that era is now old. Now the era of ChatGPT-like algorithms has arrived.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #1B1B2F; padding: 30px; border-radius: 15px; border-left: 8px solid #E43F5A; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">💬 What is ChatGPT? Decoding the Name</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">But what is this ChatGPT? Chat means talking with a machine - chatting. Just like chatbots. Bot means machine, that is, talking with a computer. And GPT means something very advanced:</p>
# <div style="background-color: #16213e; padding: 25px; border-radius: 12px; margin: 25px 0; border: 3px solid #FFD700; text-align: center;">
# <h3 style="color: #FFD700; font-size: 1.8em; margin: 10px 0;">🧠 G - P - T</h3>
# <p style="color: #E94560; font-size: 1.4em; font-weight: bold; margin: 15px 0;">Generative Pre-trained Transformers</p>
# </div>
# <ul style="color: #ffffff; font-size: 1.15em; line-height: 2;">
# <li><strong style="color: #FFD700;">Generative:</strong> They generate things using Artificial Intelligence</li>
# <li><strong style="color: #FFD700;">Pre-trained:</strong> They are already trained</li>
# <li><strong style="color: #FFD700;">Transformers:</strong> This is basically a Machine Learning architecture or workflow through which they generate</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #16213E; padding: 30px; border-radius: 15px; border-left: 8px solid #0F3460; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">📚 Understanding Large Language Models (LLMs)</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Now, as the word Large suggests, it is a very big language model. By very big, I mean it has a lot of data. You will remember I told you about AI - you train the computer by giving it data. So that is AI. Large means data that is in very high quantity - very, very much.</p>
# <h3 style="color: #E94560; margin-top: 30px;">🎯 Breaking Down LLM:</h3>
# <table style="width: 100%; border-collapse: collapse; margin: 20px 0; background-color: #0F3460;">
# <tr style="background-color: #FFD700;"><th style="padding: 15px; border: 2px solid #16213E; color: #1a1a2e; font-size: 1.2em;">Component</th><th style="padding: 15px; border: 2px solid #16213E; color: #1a1a2e; font-size: 1.2em;">Meaning</th></tr>
# <tr><td style="padding: 15px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">LARGE</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">Massive quantity of data - you give the machine lots of data and it gets trained</td></tr>
# <tr><td style="padding: 15px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">LANGUAGE</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">The data inside is language data - how we communicate with each other</td></tr>
# <tr><td style="padding: 15px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">MODEL</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">The machine has been trained. Machine means your PC, your computer - when you train it with lots of data</td></tr>
# </table>
# </div>

# %% [markdown]
# <div style="background-color: #1A1A2E; padding: 30px; border-radius: 15px; border-left: 8px solid #E94560; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🌍 Open Data: The Fuel for LLMs</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Now, what did the world do? All the data that was lying on the internet - remember that scenario when I told you we used to search on Google? Just like that. We used to search on Google and extract books too. Write PDF - all the books on that topic would appear.</p>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">📖 What is Open Data?</h3>
# <p style="color: #ffffff; font-size: 1.1em;">All this was available online. This is called <strong style="color: #FFD700;">Open Data</strong> - data that everyone can access through their websites. Open data means it is openly lying there. You can search it, download it anytime without paying anything.</p>
# </div>
# <h3 style="color: #E94560;">🤖 How LLMs Were Built:</h3>
# <ol style="color: #ffffff; font-size: 1.15em; line-height: 2;">
# <li>All the open data that was lying around - they lifted ALL of it</li>
# <li>When someone lifts this data 10-15 times, of course it becomes a stack of data</li>
# <li>This is called <strong style="color: #FFD700;">Large Data</strong></li>
# <li>It was language data because obviously they started with books</li>
# <li>They started with PowerPoints, HTML - all that open data was lifted</li>
# <li>After lifting it, they gave it to a machine - that is, a computer</li>
# <li>And the computer took training from it - that is, it got trained</li>
# </ol>
# </div>

# %% [markdown]
# <div style="background-color: #16213E; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">📊 Not Just Text: Structured & Unstructured Data</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Now, it wasn't just language data that came into this. Structured data also came in. Now you're probably understanding. Remember the lectures from yesterday and the day before? All the tabulated data, all the available data - all of it came.</p>
# <div style="display: flex; gap: 20px; margin: 30px 0;">
# <div style="flex: 1; background-color: #0F3460; padding: 20px; border-radius: 10px; border: 3px solid #E94560;">
# <h3 style="color: #E94560; text-align: center;">📋 Structured Data</h3>
# <ul style="color: #ffffff; font-size: 1.1em;"><li>Tables</li><li>Tabulated data</li><li>Organized databases</li><li>Excel sheets</li></ul>
# </div>
# <div style="flex: 1; background-color: #0F3460; padding: 20px; border-radius: 10px; border: 3px solid #FFD700;">
# <h3 style="color: #FFD700; text-align: center;">🖼️ Unstructured Data</h3>
# <ul style="color: #ffffff; font-size: 1.1em;"><li>Images</li><li>Videos</li><li>Audio files</li><li>Raw text</li></ul>
# </div>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #0F3460; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🏢 The Data Giants: Google & Meta</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Who has the data? The biggest name that will come to your mind first is <strong style="color: #FFD700;">Google</strong>. And by the way, Google owns YouTube too. When videos come on YouTube, there's image data there, video data there, audio data there.</p>
# <h3 style="color: #E94560;">🔄 Model Names & Versions:</h3>
# <table style="width: 100%; border-collapse: collapse; margin: 20px 0; background-color: #1a1a2e;">
# <tr style="background-color: #FFD700;"><th style="padding: 15px; border: 2px solid #16213E; color: #1a1a2e;">Company</th><th style="padding: 15px; border: 2px solid #16213E; color: #1a1a2e;">Model Name</th><th style="padding: 15px; border: 2px solid #16213E; color: #1a1a2e;">Type</th></tr>
# <tr><td style="padding: 15px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">Google</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">Bard → Gemini (1, 2, 3...)</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">Proprietary/Paid</td></tr>
# <tr><td style="padding: 15px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">OpenAI</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">ChatGPT (1, 2, 3, 4, 5, Omni...)</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">Proprietary/Paid</td></tr>
# <tr><td style="padding: 15px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">Meta</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">LLaMA (1, 2, 3...)</td><td style="padding: 15px; border: 2px solid #FFD700; color: #ffffff;">Open Source/Free</td></tr>
# </table>
# </div>

# %% [markdown]
# <div style="background-color: #2D132C; padding: 30px; border-radius: 15px; border-left: 8px solid #EE4540; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🔒 Proprietary vs 🌐 Open Source Models</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Google said, I won't give the code of my models to anyone. That is, what's inside this model - I will not give it to people. ChatGPT people also say, I won't give it. And they started selling it.</p>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">💰 What Does Selling Mean?</h3>
# <p style="color: #ffffff; font-size: 1.1em;">These are <strong style="color: #FFD700;">Proprietary Models</strong>. You need to understand this. Proprietary models mean <strong style="color: #FFD700;">Paid Models</strong>. Paid models mean you cannot actually find their code, and you cannot make changes yourself.</p>
# </div>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border-left: 5px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🆓 Open Source Means:</h3>
# <ul style="color: #ffffff; font-size: 1.1em; line-height: 1.8;"><li>You can download it</li><li>You can mold it according to yourself</li><li>You can utilize it</li><li>It is free!</li></ul>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #1B1B2F; padding: 30px; border-radius: 15px; border-left: 8px solid #E43F5A; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">⚠️ The WhatsApp Reality Check</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">By the way, I forgot WhatsApp here. Where you send audio messages - God knows how many during the day to your family - Should I bring guavas or not? Is there yogurt for raita or not? Just imagine - all this data is with WhatsApp people.</p>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🗑️ The Delete Myth</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Even what you say - Look at Pakistan's plight and then delete - WhatsApp people don't delete. You forget this. When something is digitized, it doesn't get deleted from anywhere. Do whatever you want.</p>
# </div>
# <div style="background-color: #16213e; padding: 20px; border-radius: 10px; margin-top: 20px; border: 2px dashed #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🚨 Important Warning:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Never make private videos or pictures of your home even for fun. Remember this - especially Gen Z and Gen Alpha listening - children? Your Beta Gamma will also do the same. So because of this, you have to walk a bit carefully.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #16213E; padding: 30px; border-radius: 15px; border-left: 8px solid #0F3460; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🇨🇳 China Enters the Game: Alibaba & DeepSeek</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">All these models were running in the world. They were running very well. China said, Why should I stay behind? There's a Chinese company called <strong style="color: #FFD700;">Alibaba</strong>. You know it, right? Alibaba - not the 40 thieves one. This Alibaba is a Chinese company on which you do shopping, pick up big stocks.</p>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #E94560;">
# <h3 style="color: #E94560; margin-top: 0;">🌟 Qwen Model</h3>
# <p style="color: #ffffff; font-size: 1.1em;">They launched a model called <strong style="color: #FFD700;">Qwen</strong>. Qwen belongs to Alibaba. They also said it's open source - take it. China disrupted the market of those above. Then what did China do? Launched a model called <strong style="color: #FFD700;">DeepSeek</strong>.</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🧠 DeepSeek: The Reasoning Revolution</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Maybe you remember - the whole West got against China that China launched this model. And this was a <strong style="color: #FFD700;">Reasoning Model</strong>. Earlier models used to give answers based only on what they had learned. Now what do models do? A new layer has come inside them. They think first. They verify the answer they have to give. Then think, then verify again. So after running 101 loops, they give you the answer.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #1A1A2E; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🚀 DeepSeek's Game-Changing Impact</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">DeepSeek came. The whole West said, Now the Chinese will take our data. We won't use this, we won't promote it. China didn't care. They said, Okay, you don't do it.</p>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #E94560;">
# <h3 style="color: #E94560; margin-top: 0;">💡 The DeepSeek Open Source Meaning:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Now listen to this. If you're building an application, and you need a Large Language Model on the backend on your own computer - that is, a Large Language Model on the backend on your own computer, and you want to give that same to customers - then you can use the <strong style="color: #FFD700;">DeepSeek model</strong> in your company.</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0;">
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin: 0;">⚠️ Listen Carefully - This is Reality, Not Theory!</p>
# <p style="color: #ffffff; font-size: 1.1em; margin-top: 10px;">So if you're feeling sleepy, I request you to do this with your mouth once. Believe me, sleep will go away.</p>
# </div>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">So open source community - DeepSeek came. DeepSeek did such work that the level was set. Meanwhile, one company was doing very good work. Its name is <strong style="color: #FFD700;">Claude</strong>. It's basically called Claude. We Pakistanis, our accent is such, but it's called Claude. This is <strong style="color: #FFD700;">Anthropic</strong> company.</p>
# </div>

# %% [markdown]
# <div style="background-color: #16213E; padding: 30px; border-radius: 15px; border-left: 8px solid #E94560; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🛡️ Claude (Anthropic) & The Military Controversy</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">This company's Claude came. And this company digitized all the data that was lying around - paid or non-paid, or books, whatever data was available online, or digital data. And their model was being used in the US military too.</p>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">⚔️ The Military Ban Story:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">But two to three days ago, the US military said, We will use Claude and we will not put any safety layer in it. We want it to come to us as-is, and all the world's data should come to us as-is. So Claude (Anthropic) people said, No sir, we cannot do this. So the US people banned it in the military.</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0;">
# <h3 style="color: #FFD700; margin-top: 0;">🚀 Grok - Elon Musk's Model:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">You all know Elon Musk, right? That Elon Musk - the rocket guy who made rockets from garbage. He bought X. X means Twitter - the old Twitter. After buying it, since every social media has data too... Not just the company, your website, but its backend data too. He bought that data and launched a model called <strong style="color: #FFD700;">Grok</strong>. This is also a proprietary model. Not open source. This is also a paid model.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #2D132C; padding: 30px; border-radius: 15px; border-left: 8px solid #EE4540; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🎯 Military Applications & Manus AI</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">How can it be used in the military? For target identification, for computer vision, there are many other things - like your live camera is running on satellite. It tells where what activity is happening. So these kinds of things happen.</p>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">📡 Multi-Modal Capabilities:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Now in these models, there's not just text. There are images too, videos too. If you train any model on images and videos, then you can also get that model trained on live video feed. Live video feed, satellite data, imagery data - they're being trained on all data. So this model came here.</p>
# </div>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #E94560;">
# <h3 style="color: #E94560; margin-top: 0;">🤖 Manus AI Enters:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">At this time, another model came forward. Then the Chinese - what do they say - started launching models blindly. They launched a model called <strong style="color: #FFD700;">Manus AI</strong>. What does Manus AI do? You just have to write Make this website for me. This thing automatically does all the work using all agentic AI. Within 5 to 10 minutes, your entire website is made. 5 to 10 minutes - entire website - and without any error.</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0;">
# <h3 style="color: #FFD700; margin-top: 0;">📊 Data Analysis Dashboard:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Manus AI did one more thing. You tell it your results - whatever your data results are. Brother, it's giving you complete data report dashboards online for free. There are some credits. Then they started charging on top of it.</p>
# <p style="color: #ffffff; font-size: 1.1em; margin-top: 15px;">Again, if you give $1 per month and your 10 data science reports are being made, who would be crazy not to use it? So people shifted to Manus AI.</p>
# </div>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px dashed #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">💰 The Meta Acquisition:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Now what happened recently? Manus AI was bought by Meta, and this was China's biggest Large Language Model deal. Now you will see Manus AI coming on the left side in Facebook. Which Americans call Manus AI (different pronunciation). So Meta did the deal.</p>
# <p style="color: #E94560; font-size: 1.1em; font-weight: bold; margin-top: 15px;">Reason: This was the model having capability to actually create a bigger impact onward.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #1B1B2F; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🌟 Kimi.com & The Current LLM Landscape</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">This came. Then recently <strong style="color: #FFD700;">kimi.com</strong> came, which gives you so many credits for free that you can easily get any work done. And Kimi is on top at the moment.</p>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #E94560;">
# <h3 style="color: #E94560; margin-top: 0;">💵 Pricing Comparison:</h3>
# <table style="width: 100%; border-collapse: collapse; margin-top: 15px;">
# <tr style="background-color: #16213e;"><th style="padding: 12px; border: 2px solid #FFD700; color: #FFD700;">Model</th><th style="padding: 12px; border: 2px solid #FFD700; color: #FFD700;">Cost</th><th style="padding: 12px; border: 2px solid #FFD700; color: #FFD700;">Notes</th></tr>
# <tr><td style="padding: 12px; border: 2px solid #E94560; color: #ffffff;">ChatGPT Plus/Paid</td><td style="padding: 12px; border: 2px solid #E94560; color: #FFD700; font-weight: bold;">$19-22/month</td><td style="padding: 12px; border: 2px solid #E94560; color: #ffffff;">Good models</td></tr>
# <tr><td style="padding: 12px; border: 2px solid #E94560; color: #ffffff;">Claude (Anthropic)</td><td style="padding: 12px; border: 2px solid #E94560; color: #FFD700; font-weight: bold;">$19-20/month</td><td style="padding: 12px; border: 2px solid #E94560; color: #ffffff;">Per model</td></tr>
# <tr style="background-color: #1a472a;"><td style="padding: 12px; border: 2px solid #FFD700; color: #FFD700; font-weight: bold;">Kimi.com</td><td style="padding: 12px; border: 2px solid #FFD700; color: #00ff00; font-weight: bold;">FREE</td><td style="padding: 12px; border: 2px solid #FFD700; color: #ffffff;">Lots of credits!</td></tr>
# </table>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0; border-left: 5px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🎯 Recommendation:</h3>
# <p style="color: #ffffff; font-size: 1.2em; font-weight: bold; margin: 0;">If you don't want to pay - use kimi.com and go there and use Large Language Models!</p>
# </div>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Now you'll be thinking, Large Language Model, Large Language Model, Large Language Model - what is this? <strong style="color: #FFD700;">This is Artificial Intelligence.</strong></p>
# </div>

# %% [markdown]
# <div style="background-color: #16213E; padding: 30px; border-radius: 15px; border-left: 8px solid #0F3460; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🧠 What is Artificial Intelligence?</h2>
# <div style="background-color: #1a1a2e; padding: 25px; border-radius: 12px; margin: 25px 0; border: 3px solid #FFD700; text-align: center;">
# <p style="color: #FFD700; font-size: 1.5em; font-weight: bold; margin: 10px 0;">🤖 AI = Artificial Intelligence</p>
# <p style="color: #ffffff; font-size: 1.2em; margin: 15px 0;">One branch of it is LLMs</p>
# </div>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Artificial Intelligence means that you train the machine by giving it data and get any work done from it. Simple. No more than that. This is what we call AI.</p>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #E94560;">
# <h3 style="color: #E94560; margin-top: 0;">🌍 Recent AI Events:</h3>
# <ul style="color: #ffffff; font-size: 1.1em; line-height: 1.8;">
# <li><strong style="color: #FFD700;">Indus AI Week</strong> happened recently in Islamabad, Pakistan</li>
# <li><strong style="color: #FFD700;">AI Summit</strong> happened recently in India</li>
# <li>The world is doing big events to show that whoever is ahead in the AI race - Data is New Oil - whoever is ahead in the data race is dominating the world right now</li>
# </ul>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0;">
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin: 0;">💭 Food for Thought:</p>
# <p style="color: #ffffff; font-size: 1.1em; margin-top: 10px;">Look, those who have big companies are doing big things. What are we doing? We are spending billions of rupees today to find out what people using WhatsApp are talking about. Just that should reach us. The fire-walla is watching it. Understand the point?</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #1A1A2E; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">📊 The Role of a Data Analyst</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">AI has come. Now what can you get done from AI? We are <strong style="color: #FFD700;">Data Analysts</strong>.</p>
# <div style="background-color: #0F3460; padding: 25px; border-radius: 12px; margin: 25px 0; border: 3px solid #FFD700; text-align: center;">
# <h3 style="color: #FFD700; margin-top: 0;">🎯 Our Job:</h3>
# <p style="color: #ffffff; font-size: 1.3em; font-weight: bold; margin: 15px 0;">To Analyze Data</p>
# <p style="color: #E94560; font-size: 1.2em; margin: 10px 0;">For</p>
# <p style="color: #FFD700; font-size: 1.3em; font-weight: bold; margin: 15px 0;">Data-Driven Decision Making</p>
# </div>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">This is our work as Data Analysts. So what work do we have to get done from AI? We have to get this work done from AI: <strong style="color: #FFD700;">To Analyze Data for Data-Driven Decision Making.</strong></p>
# <div style="background-color: #16213e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #E94560;">
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin: 0;">✅ Things are clear? Any issue? Have you understood LLMs and AI up to here?</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #2D132C; padding: 30px; border-radius: 15px; border-left: 8px solid #EE4540; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🌐 Important LLM Platforms to Explore</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">Now look at the websites of all these slowly. You will gradually understand which model is doing what and how it is working. I have shown you very basic definitions. I will start with Kimi.</p>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🌟 Kimi.com (Recommended)</h3>
# <p style="color: #ffffff; font-size: 1.1em;">My favorite! It will connect with you on a simple Gmail account. So I keep a Gmail account just for these tasks. There are agents and other things in it too. We will look at them gradually. What are agents? How do they work? But for now, this is kimi.com.</p>
# </div>
# <h3 style="color: #E94560;">🔗 Other Platforms:</h3>
# <ul style="color: #ffffff; font-size: 1.15em; line-height: 2;">
# <li><strong style="color: #FFD700;">ChatGPT</strong> - You all know this. It has a free version but I use the paid version</li>
# <li><strong style="color: #FFD700;">Claude (Anthropic)</strong> - Check its pricing. It's quite substantial pricing</li>
# <li><strong style="color: #FFD700;">Meta AI</strong> - Inside your apps, also in WhatsApp</li>
# <li><strong style="color: #FFD700;">Gemini</strong> - Your Google Gemini</li>
# <li><strong style="color: #FFD700;">DeepSeek</strong> - Foreign Chinese started</li>
# <li><strong style="color: #FFD700;">Microsoft Copilot</strong> - Basically GPT at the backend</li>
# </ul>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0;">
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin: 0;">💡 Note:</p>
# <p style="color: #ffffff; font-size: 1.1em; margin-top: 10px;">Microsoft Copilot has GPT at the backend because Microsoft had a deal with ChatGPT people. If you have Windows installed and it's registered, you get Copilot inside your Windows itself.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #16213E; padding: 30px; border-radius: 15px; border-left: 8px solid #E94560; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">⚠️ CRITICAL: Supervise AI Work!</h2>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">We will get all this work done using these Large Language Models. Then we will be using everything to do Data-Driven Decision Making. This is the whole issue of Large Language Models for Data Analysts.</p>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">🎯 First Thing First:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">If you are a Data Analyst, you should have data with you. You should know where the data is. You should also know what to get done from the data. And you should also know which analyses of the data to get done.</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #EE4540;">
# <h3 style="color: #EE4540; margin-top: 0;">🚨 SECOND THING - YOU MUST SUPERVISE!</h3>
# <p style="color: #ffffff; font-size: 1.1em;">If you are getting work done from AI, you should supervise this. Don't do this at all that AI did the work and that's it - submitted the report like this.</p>
# </div>
# <div style="background-color: #1a1a2e; padding: 20px; border-radius: 10px; margin: 20px 0; border: 2px dashed #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">💼 The Job Scenario:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">Tell me one thing. You are taking a salary of 2.5 lakh, 3 lakh in a company. Your job is to recommend for Data-Driven Decision Making. You get work done from AI. Got the work done. You send it forward like this - done. Now tell me, if there's any wrong interpretation in it that AI has done - which has 10-20% chances - can you say I got it done from AI?</p>
# <p style="color: #E94560; font-size: 1.2em; font-weight: bold; margin-top: 15px;">If you say I got it done from AI - YOUR JOB IS GONE. FINISHED!</p>
# <p style="color: #ffffff; font-size: 1.1em; margin-top: 15px;">They will say, Okay brother, go. We hired you so that you do the work yourself. Secondly, if you say I didn't do this, I got it done from a friend - you will get caught there immediately.</p>
# </div>
# </div>

# %% [markdown]
# <div style="background-color: #1B1B2F; padding: 30px; border-radius: 15px; border-left: 8px solid #FFD700; margin: 20px 0;">
# <h2 style="color: #FFD700; font-family: Arial, sans-serif;">🎓 My Personal Recommendation</h2>
# <div style="background-color: #0F3460; padding: 20px; border-radius: 10px; margin: 20px 0; border: 3px solid #FFD700;">
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin: 0;">🙏 My Humble Request:</p>
# <p style="color: #ffffff; font-size: 1.15em; margin-top: 15px;">Whenever you ask an AI or ChatGPT-like algorithm or Large Language Models to do something for you - supervise it 5 to 10 times, check it, try to interpret it.</p>
# </div>
# <h3 style="color: #E94560;">📝 Humanize the Content:</h3>
# <p style="color: #ffffff; font-size: 1.15em; line-height: 1.8;">The things that ChatGPT-like algorithms use while making reports to make it humanized - you have to remove those yourself. Like M-dashes are used a lot. The long dash - ChatGPT generalizes things. We have to remove those things to make it humanized. And I will tell you the methods for this - what things to keep in mind while generating reports.</p>
# <div style="background-color: #16213e; padding: 20px; border-radius: 10px; margin: 20px 0; border-left: 5px solid #FFD700;">
# <h3 style="color: #FFD700; margin-top: 0;">💡 What I Personally Do:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">This is my practice - whenever I have to get work done from AI, I create a dashboard and explain it by myself. I explain it myself.</p>
# <p style="color: #E94560; font-size: 1.1em; font-weight: bold; margin-top: 15px;">This is the best way because ChatGPT-like algorithms cannot explain it better. You take ideas from them but write yourself.</p>
# </div>
# <div style="background-color: #801336; padding: 20px; border-radius: 10px; margin: 20px 0;">
# <h3 style="color: #FFD700; margin-top: 0;">🧠 Why This Matters:</h3>
# <p style="color: #ffffff; font-size: 1.1em;">This will improve your writing power too. Your brain will think a bit more. Otherwise, think yourself - if you want to grow up by getting work done from someone, at the end, a time will come when your personal skills will matter a lot. So you won't say that the internet is down today, I cannot work. Or my ChatGPT subscription has expired, I cannot work today. This will never happen.</p>
# <p style="color: #FFD700; font-size: 1.2em; font-weight: bold; margin-top: 15px;">Think in a way that you have to train yourself. But by using ChatGPT-like algorithms - that is, Large Language Models.</p>
# </div>
# </div>
