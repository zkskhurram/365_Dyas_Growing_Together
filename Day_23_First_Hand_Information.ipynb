# %% [markdown]
# <div align="center">
#
#   # 🚀 365 Days Building, Learning and Growing Together
#
#   ## 🔮 Getting AI News Before the Public
#   ### <i>(Research Papers, Patents & Leaks: The Ultimate Guide)</i>
#   ### <span style="color: #ffd700;">Day_23</span> • 11-Jan-2026
#
#   ---
#
#   <strong>🖊️ Author:</strong> Khurram Shahzad &nbsp;&nbsp;&nbsp;&nbsp;
#   <strong>🎓 Mentor:</strong> Dr. Aammar Tufail
#
#   ---
#
#   <a href="mailto:khurramamq@gmail.com">✉️ Email</a> &nbsp;&nbsp;&nbsp;&nbsp;
#   <a href="https://github.com/zkskhurram/365_Dyas_Growing_Together" target="_blank">💻 GitHub</a>&nbsp;&nbsp;&nbsp;&nbsp;
#   <a href="https://www.kaggle.com/zkskhurram"> 📊kaggle</a>
#
#   ---
#
#   <span style="background: #667eea; color: white; padding: 5px 15px; border-radius: 20px;">🎯 AI Tools</span>
#   <span style="background: #1dbb79; color: white; padding: 5px 15px; border-radius: 20px;">🔎 EDA</span>
#   <span style="background: #7817c3; color: white; padding: 5px 15px; border-radius: 20px;">🐍 Python</span>
#   <span style="background: #ce4e09; color: white; padding: 5px 15px; border-radius: 20px;">🤖 Data Science</span>
# </div>
#
#
# ---

# %% [markdown]
# ## 🎯 Mission: Be First to Know AI Advancements
#
# ---
#
# <div style="background: #fff3cd; padding: 15px; border-radius: 8px; border-left: 5px solid #ffc107; color:violet;">
# <strong>🤔 Question:</strong> Who here wants to know about AI advancements <strong>BEFORE</strong> the public finds out?
# </div>
#
# Before the public gets to know - **I should get the information first!**
#
# It's just like when news starts spreading among relatives, you want to be the **first to know** so you can control the situation beforehand. 😄
#
# <div style="background: #e8f4fd; padding: 15px; border-radius: 8px; margin-top: 15px; color:violet;">
# <strong>💡 Note:</strong> That was just a silly example about relatives! We're talking about <strong>AI NEWS</strong> here!
# </div>

# %% [markdown]
# ## 📚 Source #1: Research Papers (The Starting Point)
#
# <div style="background: #d1ecf1; padding: 15px; border-radius: 8px; border-left: 5px solid #0c5460; color:violet;">
# <strong>💭 "It's difficult. Very difficult. Especially for us because it's not in our nature."</strong>
# </div>
#
# **What to read?** Research Papers! 📖
#
# Why? Because what comes in research papers **hasn't gone public yet**. It's the **absolute starting point** of any work!
#
# If you read it and immediately start implementing it, you'll have that news **before even the public**. Simple logic! 💡

# %% [markdown]
# ### 🔍 Where to Find Research Papers?
#
# <div style="background: #f8d7da; padding: 15px; border-radius: 8px; border-left: 5px solid #dc3545; color:black;">
# <h3>🤗 Hugging Face Daily Papers</h3>
# </div>
#
# Remember? I told you about this website at the start and wrote that you should **subscribe** to it!
#
# **Website:** [`huggingface.co/daily-papers`](https://huggingface.co/papers)
#
# **What you get daily:**
# - 📄 Large Language Models
# - 🎨 Generative AI
# - 🤖 AI AI AI
# - 📊 Data Data Data
# - 👁️ Computer Vision Computer Vision
#
# <div style="background: #d4edda; padding: 15px; border-radius: 8px; margin-top: 15px; color:blue ;">
# <strong>✅ Action Step:</strong> Simply click <strong>SUBSCRIBE</strong> and login with your ID. That's it!
# </div>
#
# **Options available:**
# - 📅 Daily Papers
# - 📅 Weekly Papers
# - 📅 Monthly Papers
#
# Read whatever your heart desires!

# %% [markdown]
# ### ⚠️ Common Pitfall Alert!
#
# <div style="background: #fff3cd; padding: 15px; border-radius: 8px; border-left: 5px solid #ffc107; color:violet;">
# <strong>🚨 Don't just join and sit!</strong> People subscribe, emails keep coming, they read and delete. You have to <strong>ACTUALLY READ THEM!</strong>
# </div>
#
# Read on a **daily basis**! Even if you miss one day, two days, three days... get back to daily reading!

# %% [markdown]
# ### 🤷 "But I Don't Understand Basics!"
#
# Some of you who don't know the basics will find this... "spiritual-ish" talk. Won't understand what's happening!
#
# <div style="background: #e7f3ff; padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3; color:black;">
# <h3>🛠️ Solution: Notebook LM (Google's Tool)</h3>
# </div>
#
# **Method:**
# 1. 📥 Take the research paper
# 2. 📝 Put it inside Notebook LM
# 3. 💬 Tell it: **"Explain to me in easy language"**
# 4. 🎧 You can even listen to it in audio!
#
# <div style="background: #d4edda; padding: 15px; border-radius: 8px; margin-top: 15px; color:blue;">
# <strong>✅ Daily Habit:</strong> Definitely look at the summary of <strong>ONE PAPER DAILY</strong> using Notebook LM!
# </div>
#
# **Alternative Tools:**
# - If ChatGPT doesn't work → **km.com** (Shahzadi website - Free, Chinese-based, amazing algorithm!)
# - Another option → **Ollama** (We'll talk about this Insha'Allah in coming days)

# %%
# 🛠️ Practical Implementation: Setting Up Your AI News Pipeline

# Step 1: Subscribe to Hugging Face Daily Papers
# Visit: https://huggingface.co/daily-papers

# Step 2: Use Notebook LM to Summarize Papers
# Visit: https://notebooklm.google.com/

# Step 3: Alternative Tools (When ChatGPT is not available)
ALTERNATIVE_TOOLS = {
    "km.com": "Free, Chinese-based, powerful algorithm",
    "Ollama": "Local LLM tool",
    "Hugging Face Spaces": "Various summarization models"
}

print("✅ Your AI News Research Pipeline is Ready!")
print("🎯 Target: Read & summarize 1 paper daily!")
# Out:
# ✅ Your AI News Research Pipeline is Ready!
# 🎯 Target: Read & summarize 1 paper daily!

# %% [markdown]
# ---
#
# ## 🔥 Source #2: Patents (Even BEFORE Research Papers!)
#
# <div style="background: #fff3cd; padding: 15px; border-radius: 8px; border-left: 5px solid #ffc107; color:blue;">
# <strong>🤔 Question:</strong> Is there anyone, any Mard-e-Mujahid or student, who wants information <strong>EVEN BEFORE</strong> this?
# </div>
#
# <div style="background: #f8d7da; padding: 15px; border-radius: 8px; margin-top: 15px; color:blue;">
# No excitement? 😕 How will this work? Let me tell you!
# </div>
#
# <div style="background: #d4edda; padding: 15px; border-radius: 8px; margin-top: 15px; color:blue;">
# <strong>💡 Important:</strong> Don't keep it to yourself! You have to <strong>SPREAD THIS INFORMATION FORWARD!</strong>
# </div>

# %% [markdown]
# ### 🏢 How Big Companies Operate?
#
# When companies like **Google, Meta, OpenAI** work on research:
#
# <div style="background: #e8f4fd; padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3; color:black">
# <strong>🚨 Secret:</strong> They <strong>DON'T PUBLISH PAPERS!</strong> 🤐
# </div>
#
# <strong>Why?</strong>
# - These are clever people! 🧠
# - Their revenue comes from it
# - Strategy is NOT to publish properly
# - Do **in-house research** & keep things with themselves
# - Until they create something out of it
#
# <div style="background: #fff3cd; padding: 15px; border-radius: 8px; margin-top: 15px; color:black;">
# <strong>💭 "Unless they create something out of it."</strong>
# </div>

# %% [markdown]
# ### 📋 The Patent Database Solution
#
# There's a **public database** where you can see their **filed patents**!
#
# <div style="background: #e7f3ff; padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;color:violet">
# <h3>💼 What Are Patents?</h3>
# </div>
#
# Patents are technologies for which you apply for copyrights:
# - **"This technology is ONLY ours!"**
# - It's like a paper, but written for authorities
# - You save your ownership (copyright)
#
# **Example:** I made a new pencil design, I want that no one can copy it. It's my ownership (malikiyat). I save it and only I can produce it. No one else can!

# %% [markdown]
# ### 🔓 How Patents Become Public?
#
# <div style="background: #d1ecf1; padding: 15px; border-radius: 8px; border-left: 5px solid #0c5460; color:blue;">
# <strong>When Google, Meta, OpenAI file patents → They get saved in PUBLIC REPOSITORY! 📂</strong>
# </div>
#
# **What you can see:**
# - Some information is **VISIBLE** 👁️
# - Some information is **NOT visible** 🙈
# - But you get an **IDEA!** 💡
#
# **Who benefits?**
# - Entrepreneurs starting their own companies
# - They can focus on this way
# - Set their company's motto accordingly

# %% [markdown]
# ### 🔍 How to Find Patents?
#
# <div style="background: #d4edda; padding: 15px; border-radius: 8px; border-left: 5px solid #28a745;color:blue;">
# <strong>✅ Simple Method:</strong> Just write on Google:
# <div style="background: white; padding: 10px; border-radius: 5px; margin-top: 10px; font-family: monospace; font-size: 16px; color:black;">
# Latest patent submitted by OpenAI
# </div>
# </div>
#
# **Result:** Tons of articles will come to you!

# %% [markdown]
# ### 🗞️ Investigative Journalists & Leaks
#
# Some **investigative journalists** in Data Science:
# - Catch these patent things
# - Create **videos** or **blogs** in the form of leaks
# - Show: **"What's Coming Ahead"**
#
# <div style="background: #e8f4fd; padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;color:blue;">
# <strong>📱 Example:</strong> iPhone 17 Pro hadn't launched, but its pictures leaked earlier. And exactly what came was the same!
# </div>
#
# <div style="background: #fff3cd; padding: 15px; border-radius: 8px; margin-top: 15px; color:blue;">
# <strong>💭 "So somehow people find out. Either someone from in-house leaks it, or someone gets it leaked by paying money."</strong>
# </div>

# %% [markdown]
# ### 📸 Real-World Example: DJI Osmo Camera Leaks
#
# I have a camera called **DJI Osmo** that I use for my work.
#
# <div style="background: #f8f9fa; padding: 15px; border-radius: 8px; border-left: 5px solid #6c757d; color:blue;">
# <strong>📹 Current Status:</strong><br>
# - Its screen is damaged<br>
# - I've been using it as a webcam for ~2-2.5 years<br>
# - Recently bought another webcam
# </div>
#
# <div style="background: #fff3cd; padding: 15px; border-radius: 8px; margin-top: 15px; color:black;">
# <strong>🚨 Leaks Started Coming:</strong><br>
# Because it sold a LOT!
# </div>
#
# **What leaks are saying:**
# - It will have **two lenses** now 📷📷
# - Body will become **even shorter** ↕️
# - And so on...
#
# **Source of leaks:**
# - Based on **patents** 📋
# - Based on **software updates** 💻
# - Based on leaks by **high-insight people** 🕵️
#
# <div style="background: #d1ecf1; padding: 15px; border-radius: 8px; margin-top: 15px; color:violet;">
# <strong>💭 "So I mean, this is the way out to read about new things. Got it?"</strong>
# </div>

# %% [markdown]
# ### ⚠️ Truth About Leaks
#
# <div style="background: #f8d7da; padding: 15px; border-radius: 8px; border-left: 5px solid #dc3545; color:blue;">
# <strong>🎯 Key Points:</strong>
# </div>
#
# 1. **Leaks through OpenAI & patents** → NOT 100% true
# 2. **But if 50% is true** → You know what's coming! 🎯
# 3. **If you read patent yourself** → You can guess what's happening
# 4. **Through leaks** → You don't get 100% information
#
# <div style="background: #d4edda; padding: 15px; border-radius: 8px; margin-top: 15px; color:blue;">
# <strong>✅ Pro Tip:</strong> Find such people about whom you want to get information. Could be tech, could be anything!
# </div>

# %%
# 🔥 Implementation: Patent Monitoring System

import requests
from datetime import datetime, timedelta

def get_ai_patents(company="OpenAI", days=30):
    """
    Monitor latest patents from AI companies
    """
    # Note: This is a conceptual implementation
    # Real implementation would use patent database APIs
    
    patent_sources = {
        "OpenAI": "https://patents.google.com/?assignee=OpenAI",
        "Google": "https://patents.google.com/?assignee=Google",
        "Meta": "https://patents.google.com/?assignee=Meta",
        "Microsoft": "https://patents.google.com/?assignee=Microsoft"
    }
    
    return patent_sources.get(company, "Company not found")

# 📋 Patent Monitoring Dashboard
companies_to_track = ["OpenAI", "Google", "Meta", "Microsoft"]

print("🎯 Patent Monitoring System")
print("=" * 40)

for company in companies_to_track:
    print(f"\n🔍 {company}:")
    print(f"   Link: {get_ai_patents(company)}")
    print(f"   Action: Search 'latest patent submitted by {company}'")

print("\n✅ Weekly Task: Review latest patents from target companies!")
# Out:
# 🎯 Patent Monitoring System
# ...
#
# 🔍 OpenAI:
#    Link: https://patents.google.com/?assignee=OpenAI
#    Action: Search 'latest patent submitted by OpenAI'
#
# 🔍 Google:
#    Link: https://patents.google.com/?assignee=Google
#    Action: Search 'latest patent submitted by Google'
#
# 🔍 Meta:
#    Link: https://patents.google.com/?assignee=Meta
#    Action: Search 'latest patent submitted by Meta'
#
# 🔍 Microsoft:
#    Link: https://patents.google.com/?assignee=Microsoft
#    Action: Search 'latest patent submitted by Microsoft'
#
# ✅ Weekly Task: Review latest patents from target companies!

# %% [markdown]
# ---
#
# ## 🎯 Final Action Plan
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 25px; border-radius: 15px; color: white;">
# <h2 style="text-align: center; margin-bottom: 20px;">🚀 Your AI Intelligence Pipeline</h2>
#
# <div style="display: flex; justify-content: space-around; flex-wrap: wrap; gap: 15px;">
# <div style="display: flex; gap: 15px; flex-wrap: wrap;">
#   <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; flex: 1; min-width: 200px;">
#     <h3>📄 Level 1: Daily Papers</h3>
#     <p>Subscribe to HF Daily Papers</p>
#     <p>Use NotebookLM to understand</p>
#   </div>
#
#   <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; flex: 1; min-width: 200px;">
#     <h3>📋 Level 2: Patents</h3>
#     <p>Monitor company patents</p>
#     <p>Search “latest patent by [company]”</p>
#   </div>
#
#   <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; flex: 1; min-width: 200px;">
#     <h3>🗞️ Level 3: Leaks</h3>
#     <p>Follow investigative journalists</p>
#     <p>Watch for product leaks</p>
#   </div>
# </div>

# %% [markdown]
# ---
#
# ## 📱 Connect & Learn More
#
# <div style="background: #f8f9fa; padding: 20px; border-radius: 10px; text-align: center;">
#
# [![GitHub](https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white)](https://github.com/zkskhurram)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/khurram-shahzad-939158341/)
# [![YouTube](https://img.shields.io/badge/YouTube-FF0000?style=for-the-badge&logo=youtube&logoColor=white)](https://www.youtube.com/@multimoldyke8432)
# [![Twitter](https://img.shields.io/badge/Twitter-1DA1F2?style=for-the-badge&logo=twitter&logoColor=white)](https://x.com/DaneenElla21492)
# [![Codanics](https://img.shields.io/badge/Codanics-22C55E?style=for-the-badge&logo=code&logoColor=white)](https://codanics.com/)
#
# <div style="margin-top: 20px;">
# <strong>📧 Email:</strong> khurramamq@gmail.com<br>
# <strong>🎓 Mentor:</strong> Dr. Aammar Tufail
# </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 25px; border-radius: 15px; color: white; text-align: center;">
# <h2>🏆 Challenge: Start Today!</h2>
# <p style="font-size: 18px;">Read 1 research paper daily for next 7 days using Notebook LM</p>
# <p style="font-size: 16px; margin-top: 15px;">Track 1 patent from your favorite AI company</p>
# <p style="font-size: 20px; margin-top: 20px;"><strong>🎯 Be the First to Know!</strong></p>
# </div>
